# %%
from pathlib import Path
from cfclone.plot.plot_ctdna import plot_ctdna
from cfclone.plot.plot_clones_from_tsv import plot_clones_from_tsv

out_dir = Path('results')
out_dir.mkdir(exist_ok=True, parents=True)
ctdna_file = "data/VOA10055P_proc.tsv.gz"
clone_cn_file = "data/clone_cn.tsv.gz"
ctdna_plot_file = out_dir.joinpath('ctdnas.png')
clone_cn_plot_file = out_dir.joinpath('clone_cn.png')
plot_ctdna(ctdna_file, plot_file=out_dir.joinpath('rdr.png'), yvar='rdr', title='RDR')
plot_ctdna(ctdna_file, plot_file=out_dir.joinpath('baf.png'), yvar='baf', title='BAF')
plot_clones_from_tsv(clone_cn_file, clone_cn_plot_file)

# %% [markdown]
# ![Alt text](results/rdr.png)
# ![Alt text](results/baf.png)
# ![Alt text](results/clone_cn.png)

# %%
from cfclone.run import fit

fit(
    in_file=ctdna_file,
    clone_cnv_file=clone_cn_file,
    out_file=out_dir.joinpath('fit.h5'),
    add_normal=True,
    outlier=True,
    num_chains=2,
    num_rounds=2,
    num_threads=2,
    use_clone='8',
    num_bins=300,
)
# Out:
# Analysing using 2 clones and 300 bins
# ['8', 'normal']
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
#
# Using 2 threads
# [ Info: auto_non_convex_newton started. Initial value = -3127.2956535884136
# [ Info: gradient infinity norm = 250.0447803887336
# [ Info: Smallest eig value of negative Hessian = -45.68052686559909
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 2
# [ Info: Value at iteration 1 = -2520.7540762729004 (step size = 0.5)
# [ Info: gradient infinity norm = 1252.839681006124
# [ Info: Smallest eig value of negative Hessian = -377.9644983768825
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 2
# [ Info: Value at iteration 2 = -2354.8872756080823 (step size = 0.25)
# [ Info: gradient infinity norm = 243.53541527138827
# [ Info: Smallest eig value of negative Hessian = -42.88358727995765
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 2
# [ Info: Value at iteration 3 = -2110.162670976911 (step size = 0.125)
# [ Info: gradient infinity norm = 971.965551521132
# [ Info: Smallest eig value of negative Hessian = -18.000566821929464
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 4
# [ Info: Value at iteration 4 = -1765.6850540794173 (step size = 0.25)
# [ Info: gradient infinity norm = 473.35908834477436
# [ Info: Smallest eig value of negative Hessian = -2.7996683179406903
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 2
# [ Info: Value at iteration 5 = -1249.502076012601 (step size = 0.125)
# [ Info: gradient infinity norm = 708.4700763672095
# [ Info: Smallest eig value of negative Hessian = 6.349338927503952
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 4
# [ Info: Value at iteration 6 = -1196.722052150507 (step size = 0.25)
# [ Info: gradient infinity norm = 467.5802052392255
# [ Info: Smallest eig value of negative Hessian = 10.06058474569516
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 4
# [ Info: Value at iteration 7 = -1167.727729667119 (step size = 0.5)
# [ Info: gradient infinity norm = 192.88027594160985
# [ Info: Smallest eig value of negative Hessian = 8.617651234230694
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 4
# [ Info: Value at iteration 8 = -1156.5593861688508 (step size = 1.0)
# [ Info: gradient infinity norm = 20.504799693544488
# [ Info: Smallest eig value of negative Hessian = 6.796761559080625
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 3
# [ Info: Value at iteration 9 = -1155.5270530392688 (step size = 1.0)
# [ Info: gradient infinity norm = 3.882382563883377
# [ Info: Smallest eig value of negative Hessian = 6.573621923067925
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 3
# [ Info: Value at iteration 10 = -1155.4953564494888 (step size = 1.0)
# [ Info: gradient infinity norm = 0.07756888313196253
# [ Info: Smallest eig value of negative Hessian = 6.569150025055978
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 3
# [ Info: Value at iteration 11 = -1155.495307497436 (step size = 1.0)
# [ Info: gradient infinity norm = 0.00013538961817283202
# [ Info: Smallest eig value of negative Hessian = 6.569135526277174
# [ Info: Selected auto index (1 to stay, 2 shrink, 3 to keep, 4 to grow): 3
# [ Info: Value at iteration 12 = -1155.4953074973398 (step size = 1.0)
# [ Info: gradient infinity norm = 3.9499936654863177e-10
# ┌ Warning: At the moment, for StanLogPotential please use a single thread
# │ (but several MPI processes can still be used).
# └ @ PigeonsBridgeStanExt ~/.julia/packages/Pigeons/y3Kae/ext/PigeonsBridgeStanExt/interface.jl:26
# ┌ Warning: Loading a shared object '/home/matteo/projects/cfdna/wfs/src/tmp-cfclone/cfclone/src/cfclone/stan/cfclone_outlier_model.so' which is already loaded.
# │ If the file has changed since the last time it was loaded, this load may not update the library!
# └ @ BridgeStan ~/.julia/packages/BridgeStan/lLxtM/src/model.jl:51
# [ Info: Finding a stepsize for NUTS
# Sampling   0%|                               |  ETA: 0:08:42
#                                     iterations: 2
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.5
#                                        n_steps: 1
#                                      is_accept: true
#                                acceptance_rate: 0.0
#                                    log_density: -1155.4953074973398
#                             hamiltonian_energy: 1162.843582678126
#                       hamiltonian_energy_error: 0.0
#                   max_hamiltonian_energy_error: 1579.1938771338546
#                                     tree_depth: 0
#                                numerical_error: true
#                                      step_size: 3.7361749653017813
#                                  nom_step_size: 3.7361749653017813
#                                       is_adapt: true
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling 100%|███████████████████████████████| Time: 0:00:03
#                                     iterations: 1000
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.0
#                                        n_steps: 7
#                                      is_accept: true
#                                acceptance_rate: 0.7993694320369595
#                                    log_density: -1157.2678717190533
#                             hamiltonian_energy: 1160.690560884184
#                       hamiltonian_energy_error: 0.06620923139098522
#                   max_hamiltonian_energy_error: 0.38998429684420444
#                                     tree_depth: 3
#                                numerical_error: false
#                                      step_size: 0.6723485877675555
#                                  nom_step_size: 0.6723485877675555
#                                       is_adapt: true
#                                    mass_matrix: DenseEuclideanMetric([6.51329e-5, 2.49775e-6, 0. ...])
# ┌ Info: Finished 1000 sampling steps for 1 chains in 3.436629501 (s)
# │   h = Hamiltonian with DenseEuclideanMetric and GaussianKinetic
# │   κ = AdvancedHMC.HMCKernel{AdvancedHMC.FullMomentumRefreshment, AdvancedHMC.Trajectory{AdvancedHMC.SliceTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}}(AdvancedHMC.FullMomentumRefreshment(), Trajectory{AdvancedHMC.SliceTS} with Leapfrog with step size ϵ=0.908 and termination criterion AdvancedHMC.GeneralisedNoUTurn{Float64}(10, 1000.0))
# │   EBFMI_est = 1.0737121207786056
# └   average_acceptance_rate = 0.7949402099310565
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   scans     restarts      Λ        time(s)  log(Z₁/Z₀)   min(α)     mean(α)    max|ρ|     mean|ρ|    min(αₑ)   mean(αₑ)
# ────────── ────────── ────────── ────────── ────────── ────────── ────────── ────────── ────────── ────────── ──────────
#         2          0      0.542       1.83  -1.15e+03      0.458      0.458          1          1      0.871      0.871
#         4          1      0.151     0.0282  -1.15e+03      0.849      0.849      0.702      0.702      0.933      0.933
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
from cfclone.run.postprocess import write_parameter_summaries
from cfclone.plot.plot_fit import plot_fit

write_parameter_summaries(
    in_file=out_dir.joinpath('fit.h5'),
    out_file=out_dir.joinpath('parameter_summaries.tsv'),
)
plot_fit(
    in_file=out_dir.joinpath('parameter_summaries.tsv'),
    out_file=out_dir.joinpath('fit.png')
)
# Out:
# mu and p dataframes built
#
# mu and p residuals computed
#
# RDR and BAF outlier probs computed
#
# mu summary dataframe built
# mu summary col processing complete
#
# p summary dataframe built
# p summary col processing complete
#
# mu_residual summary dataframe built
# mu_residual summary col processing complete
#
# p_residual summary dataframe built
# p_residual summary col processing complete
#
# baf_outlier_odds summary dataframe built
# baf_outlier_odds summary col processing complete
#
# rdr_outlier_odds summary dataframe built
# rdr_outlier_odds summary col processing complete
#
# baf_outlier_prob summary dataframe built
# baf_outlier_prob summary col processing complete
#
# rdr_outlier_prob summary dataframe built
# rdr_outlier_prob summary col processing complete

# %% [markdown]
# ![Alt text](results/fit.png)
